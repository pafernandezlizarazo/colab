# %% [markdown]
# <a href="https://colab.research.google.com/github/pafernandezlizarazo/colab/blob/main/AEPPaulaFernandez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/pafernandezlizarazo/colab/main/dataset.csv')
df
# Out:
#          LONCOD     LATCOD  CDCODE  year                            school  \
# 0    -75.584900  39.668100  1000.0  2009          William Penn High School
# 1    -87.617500  41.839900  1701.0  2009  Dunbar Vocational Career Academy
# 2    -90.165100  38.565700  1712.0  2009               Cahokia High School
# 3    -78.311800  35.831500  3713.0  2009             Zebulon Middle School
# 4    -83.113977  42.383593     NaN  2009               Central High School
# ..          ...        ...     ...   ...                               ...
# 175 -149.881113  61.213281   200.0  2018          Denali Elementary School
# 176  -77.378427  37.471892  5104.0  2018                Varina High School
# 177  -80.691593  35.120282  3709.0  2018                Butler High School
# 178  -76.382449  36.826811  5103.0  2018      Simonsdale Elementary School
# 179  -83.229837  36.784261  2105.0  2018          Cawood Elementary School
#
# ...

# %%
df.head(2)
# Out:
#     LONCOD   LATCOD  CDCODE  year                            school  \
# 0 -75.5849  39.6681  1000.0  2009          William Penn High School
# 1 -87.6175  41.8399  1701.0  2009  Dunbar Vocational Career Academy
#
#          city     state         address  urbanrural   race  killed  injured  \
# 0  New Castle  Delaware  713 E Basin Rd  suburbtown  BLACK       0        1
# 1     Chicago  Illinois  3000 S King Dr       urban  BLACK       0        5
#
#    victims      date         type       NCESSCH    time
# 0        1  8-Jan-09  High School  1.000230e+11  8:30PM
# 1        5  9-Jan-09  High School  1.709930e+11  8:00PM

# %%
df1 = df[['LONCOD', 'LATCOD', 'CDCODE', 'year', 'school', 'city', 'state', 'address', 'urbanrural', 'race', 'killed', 'injured', 'victims', 'date', 'type', 'NCESSCH', 'time']]
df1
# Out:
#          LONCOD     LATCOD  CDCODE  year                            school  \
# 0    -75.584900  39.668100  1000.0  2009          William Penn High School
# 1    -87.617500  41.839900  1701.0  2009  Dunbar Vocational Career Academy
# 2    -90.165100  38.565700  1712.0  2009               Cahokia High School
# 3    -78.311800  35.831500  3713.0  2009             Zebulon Middle School
# 4    -83.113977  42.383593     NaN  2009               Central High School
# ..          ...        ...     ...   ...                               ...
# 175 -149.881113  61.213281   200.0  2018          Denali Elementary School
# 176  -77.378427  37.471892  5104.0  2018                Varina High School
# 177  -80.691593  35.120282  3709.0  2018                Butler High School
# 178  -76.382449  36.826811  5103.0  2018      Simonsdale Elementary School
# 179  -83.229837  36.784261  2105.0  2018          Cawood Elementary School
#
# ...

# %%
sns.set_style('whitegrid');

text_dict = {'size':16,'color':'purple'};
plt.figure(figsize=(8,6));
plt.hist(df1['LATCOD'],color='pink');
plt.xlabel('Año de Asignación',fontdict=text_dict);
